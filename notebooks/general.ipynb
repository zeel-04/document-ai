# %%
from document_ai import DocumentProcessor
from document_ai.parser import DigitalPDFParser
from document_ai.formatter import PDFFormatter
from document_ai.schemas import Document

# %%
document = Document(
    document_type="digital_pdf",
    uri="/Users/zeel/Downloads/MCP tool review.pdf"
)

# %%
processor = DocumentProcessor(
    parser=DigitalPDFParser(),
    formatter=PDFFormatter(),
    document=document,
)

# %%
processed_document = processor.process(formatter_config={"flag":"complete_without_line_numbers"})

# %%
print(processed_document.model_dump()["llm_input"])
# Out:
# <page number=0>
# MMCCPP SSeerrvveerr RReevviieeww:: RRoolleess aanndd RReessppoonnssiibbiilliittiieess AAnnaallyyssiiss
# WWhhaatt''ss WWoorrkkiinngg WWeellll
# 11.. CClleeaarr SSeeppaarraattiioonn ooff CCoonncceerrnnss
# Vehicle search is separate from business info search
# Contact management is distinct from booking operations
# Each tool has a single, well-defined purpose
# 22.. GGoooodd TTooooll NNaammiinngg
# Names clearly indicate what each tool does (search_vehicles, save_user_contact_details)
# Follows consistent naming conventions
# 33.. SSttaatteeffuull CCoonntteexxtt MMaannaaggeemmeenntt
# Smart use of config to inject context (contact_id, account_id, etc.)
# Reduces parameter burden on the LLM
# CCrriittiiccaall IIssssuueess TThhaatt NNeeeedd IImmpprroovveemmeenntt
# 11.. IInnccoommpplleettee TTooooll DDeessccrriippttiioonnss
# PPrroobblleemm:: Tool descriptions lack crucial details about what they return and when to use them.
# #  Current
# @mcp.tool
# def search_vehicles(query: str) -> list[dict]:
# """Search the vehicle database based on natural language queries.
# Args:
# query: User's search query
# Returns:
# A list of dictionaries containing matching vehicle data
# """
#  IImmpprroovveedd::
# @mcp.tool
# def search_vehicles(query: str) -> list[dict]:
# """Search the vehicle inventory database using natural language.
# Use this tool when the user asks about:
# - Vehicle availability (e.g., "Do you have any SUVs?")
# - Specific models, makes, or years
# - Features, colors, or price ranges
# - Comparisons between vehicles
# Args:
# query: Natural language search query (e.g., "2023 Honda CR-V under $30k")
# Returns:
# List of matching vehicles with details like make, model, year, price, VIN, etc.
# Returns empty list if no matches found.
# Examples:
# - "certified pre-owned Toyota Camry"
# - "electric vehicles under $40,000"
# - "SUVs with third row seating"
# """
# 22.. BBrrookkeenn TTooooll CChhaaiinn LLooggiicc
# PPrroobblleemm:: create_booking() has a misleading signature and creates a confusing dependency.
# </page>
# <page number=1>
# #  Current - phone_number parameter is never used!
# @mcp.tool
# def create_booking(phone_number: str) -> str:
# """Create a booking for the user"""
# return _create_booking(...)
# IIssssuueess::
# 1. The LLM will think it needs to pass phone_number, but it's ignored
# 2. The actual implementation checks if phone exists internally
# 3. Creates unnecessary confusion about tool sequencing
#  IImmpprroovveedd::
# @mcp.tool
# def create_booking() -> str:
# """Create a booking/appointment for the current user.
# Prerequisites:
# - User's phone number must be saved first using save_user_contact_details()
# - If phone is not saved, this will return an error message
# Use this when the user:
# - Explicitly requests to book/schedule an appointment
# - Says "book me in", "schedule a visit", "make an appointment"
# - Confirms they want to proceed after discussing available times
# Returns:
# Success message with phone number if booking created,
# or error message if phone number not found.
# """
# # Remove unused phone_number parameter
# 33.. MMiissssiinngg TTooooll CCaallll GGuuiiddaannccee
# PPrroobblleemm:: No clear workflow documentation for multi-step processes.
#  AAdddd ttoo ssaavvee__uusseerr__ccoonnttaacctt__ddeettaaiillss::
# @mcp.tool
# def save_user_contact_details(phone_number: str) -> str:
# """Save or update the user's phone number.
# Use this when:
# - User provides their phone number for the first time
# - User wants to update their contact information
# - Before creating a booking (required prerequisite)
# Args:
# phone_number: Phone number in any format (will be normalized)
# Examples: "(555) 123-4567", "555-123-4567", "5551234567"
# Workflow:
# 1. Extract phone number from conversation
# 2. Call this tool to save it
# 3. Confirm with user that it's saved
# 4. Then proceed to create_booking() if needed
# Returns:
# Success confirmation message
# """
# 44.. VVaagguuee BBuussiinneessss IInnffoo TTooooll
# PPrroobblleemm:: Too broad - LLM won't know when to use it vs. search_vehicles.
# </page>
# <page number=2>
# #  Current
# def search_business_info(query: str) -> dict:
# """Search the business knowledge base for customer-facing information..."""
#  IImmpprroovveedd::
# @mcp.tool
# def search_business_info(query: str) -> dict:
# """Search dealership business information (NOT vehicle inventory).
# Use this tool ONLY for questions about:
#  Store hours: "When are you open?", "What time do you close?"
#  Location: "Where are you located?", "How do I get there?"
#  Contact: "What's your phone number?", "How can I reach you?"
#  Promotions: "Any current deals?", "Special offers?"
#  Services: "Do you offer financing?", "Can I trade in my car?"
#  Financing: "What credit score do I need?", "APR rates?"
# Do NOT use for:
#  Vehicle searches (use search_vehicles instead)
#  Specific vehicle pricing (use search_vehicles)
#  Inventory questions (use search_vehicles)
# Args:
# query: Specific question about business operations
# Returns:
# Dictionary with relevant business information
# """
# 55.. IInnccoommpplleettee UUnnssuubbssccrriibbee TTooooll
# #  Current - Missing description entirely!
# @mcp.tool
# def unsubscribe_from_follow_up_messages():
# return _unsubscribe_from_follow_up_messages(contact_id=config.contact_id)
#  IImmpprroovveedd::
# @mcp.tool
# def unsubscribe_from_follow_up_messages() -> str:
# """Unsubscribe the user from automated follow-up messages.
# Use this when the user:
# - Explicitly requests to unsubscribe or opt-out
# - Says "stop messaging me", "unsubscribe", "don't contact me"
# - Wants to stop receiving marketing/follow-up communications
# Important:
# - This is permanent for this conversation
# - Confirm with user before calling
# - Let them know they can resubscribe by contacting the dealership
# Returns:
# Confirmation message of unsubscription
# """
# 66.. MMiissssiinngg EErrrroorr CCoonntteexxtt
# Your error messages don't help the LLM recover:
# </page>
# <page number=3>
# #  Current
# if not user_details:
# return "No Contact Details Found"
#  IImmpprroovveedd::
# if not user_details:
# return {
# "status": "error",
# "message": "No contact details found for this user",
# "next_action": "Ask the user for their phone number and use save_user_contact_details() to store it"
# }
# RReeccoommmmeennddeedd TTooooll SSeeqquueenncciinngg DDooccuummeennttaattiioonn
# Add this as a comment or separate resource file:
# """
# TOOL USAGE WORKFLOWS
# ====================
# 1. VEHICLE INQUIRY FLOW:
# search_vehicles() → Discuss results → [Optional: search_business_info() for financing]
# 2. APPOINTMENT BOOKING FLOW:
# a. get_user_contact_details() → Check if phone exists
# b. If no phone: save_user_contact_details(phone)
# c. create_booking()
# d. Confirm booking with user
# 3. BUSINESS QUESTIONS:
# search_business_info() → Provide answer
# 4. OPT-OUT FLOW:
# Confirm user intent → unsubscribe_from_follow_up_messages()
# """
# AAddddiittiioonnaall IImmpprroovveemmeennttss
# 77.. RReettuurrnn SSttrruuccttuurreedd DDaattaa
# # Instead of strings, return dicts for better parsing:
# def create_booking() -> dict:
# # ...
# return {
# "status": "success",
# "booking_id": booking.id,
# "phone": customer.get('phone'),
# "message": "Booking created successfully"
# }
# 88.. AAdddd TTooooll PPaarraammeetteerr VVaalliiddaattiioonn EExxaammpplleess
# </page>
# <page number=4>
# @mcp.tool
# def save_user_contact_details(phone_number: str) -> str:
# """...
# Args:
# phone_number: Valid phone number
#  Good: "555-123-4567", "(555) 123-4567", "5551234567"
#  Bad: "call me later", "555-CALL", "unknown"
# """
# SSuummmmaarryy:: PPrriioorriittyy FFiixxeess
# 1. HHiigghh PPrriioorriittyy::
# Fix create_booking() parameter mismatch
# Add detailed "when to use" guidance to all tools
# Distinguish search_vehicles vs search_business_info clearly
# 2. MMeeddiiuumm PPrriioorriittyy::
# Return structured dictionaries instead of strings
# Add workflow documentation
# Improve error messages with next-step guidance
# 3. LLooww PPrriioorriittyy::
# Add parameter validation examples
# Consider tool for reading subscription status (per your TODO)
# These changes will dramatically improve the LLM's ability to choose the right tool at the right time and handle error cases gracefully.
# </page>
