# %%
from dotenv import load_dotenv
load_dotenv()
from document_ai.llm import OpenAILLM
from pydantic import BaseModel
from document_ai import DocumentProcessor
from document_ai.parser import DigitalPDFParser
from document_ai.formatter import PDFFormatter
from document_ai.schemas import Document
from document_ai.extractor import PDFExtractor
from document_ai.schemas import Mode

# %%
class EndingBalance(BaseModel):
    ending_balance: float
    page_number_citation: int
    line_number_citations: list[int]

# %%
llm = OpenAILLM()

# %%
processor = DocumentProcessor(
    parser=DigitalPDFParser(),
    formatter=PDFFormatter(),
    extractor=PDFExtractor(llm),
    document=Document(
        document_type="digital_pdf",
        uri="/Users/zeel/Public/ms/open_source/document_ai/data/Bank_eStmt_2025-07-14.pdf"
    ),
    mode=Mode(paginated=False, include_line_numbers=True)
)

# %%
processor.parse()
llm_input = processor.formatted_input_for_llm()

# %%
processor.document.content.pages[0].lines
# Out:
# [Line(text='P.O. Box 15284 Customer service information', bounding_box=BoundingBox(x0=0.06470588235294118, top=0.10988135363636356, x1=0.8684772147058823, bottom=0.12555682818181813)),
#  Line(text='Wilmington, DE 19850', bounding_box=BoundingBox(x0=0.06470588235294118, top=0.12109347484848476, x1=0.18169214196078434, bottom=0.12993180818181824)),
#  Line(text='Customer service: 1.800.432.1000', bounding_box=BoundingBox(x0=0.6529411764705881, top=0.15628910090909087, x1=0.8773563370588234, bottom=0.16828410090909088)),
#  Line(text='En Español: 1.800.688.6086', bounding_box=BoundingBox(x0=0.6529411764705881, top=0.17992546454545455, x1=0.8357859005882352, bottom=0.19192046454545456)),
#  Line(text='ZEEL DIPENKUMAR THUMAR bankofamerica.com', bounding_box=BoundingBox(x0=0.07352941176470588, top=0.19982575757575766, x1=0.7804466152941176, bottom=0.21373864636363635)),
#  Line(text='230 CAMPBELL AVE', bounding_box=BoundingBox(x0=0.07352941176470588, top=0.21346212121212121, x1=0.20114705882352943, bottom=0.2248257575757576)),
#  Line(text='WEST HAVEN, CT 06516-5338 Bank of America, N.A.', bounding_box=BoundingBox(x0=0.07352941176470588, top=0.22356182818181825, x1=0.7940912805882352, bottom=0.23846212121212118)),
#  Line(text='P.O. Box 25118', bounding_box=BoundingBox(x0=0.6529411764705881, top=0.2362891009090909, x1=0.7542594135294117, bottom=0.2482841009090909)),
#  Line(text='Tampa, FL 33622-5118', bounding_box=BoundingBox(x0=0.6529411764705881, top=0.24901637363636367, x1=0.8081861111764705, bottom=0.2610113736363637)),
#  Line(text='Your Adv SafeBalance Banking', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.38733040303030297, x1=0.45583287058823513, bottom=0.4087955545454545)),
#  Line(text='for June 11, 2025 to July 14, 2025 Account number: 3850 3327 1835', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.415224706969697, x1=0.8777476778431373, bottom=0.4291136463636364)),
#  Line(text='ZEEL DIPENKUMAR THUMAR', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.43941923242424236, x1=0.2824664256862745, bottom=0.4520454445454545)),
#  Line(text='Account summary', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.4672348484848485, x1=0.25227941176470586, bottom=0.48617424242424245)),
#  Line(text='Beginning balance on June 11, 2025 $610.52', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.49401637363636364, x1=0.5639691831372549, bottom=0.5060113736363636)),
#  Line(text='Deposits and other additions 0.00', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.517349706969697, x1=0.5636970166666666, bottom=0.5293447069696969)),
#  Line(text='ATM and debit card subtractions -418.91', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.5406830403030303, x1=0.5638735829411765, bottom=0.5526780403030302)),
#  Line(text='Other subtractions -80.00', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.562349706969697, x1=0.5637828607843137, bottom=0.574344706969697)),
#  Line(text='Service fees -0.00', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.5856830403030302, x1=0.5636921386274509, bottom=0.5976780403030303)),
#  Line(text='Ending balance on July 14, 2025 $111.61', bounding_box=BoundingBox(x0=0.058823529411764705, top=0.6095707475757575, x1=0.5635455037254902, bottom=0.6221969596969696)),
#  Line(text='Invest in their future - open a 529 plan', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.7932071112121212, x1=0.5335609078431373, bottom=0.8058333233333334)),
#  Line(text='The future starts now at merrilledge.com/529plan', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8105833333333333, x1=0.5798529411764706, bottom=0.8219469696969697)),
#  Line(text='Scan the code to learn more.', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8245227272727274, x1=0.43380882352941164, bottom=0.8358863636363637)),
#  Line(text='When you use the QRC feature, certain information is collected from your mobile device for business', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8406868281818182, x1=0.7939112780392159, bottom=0.8507878887878788)),
#  Line(text='purposes. Merrill Lynch, Pierce, Fenner & Smith Incorporated (also referred to as "MLPF&S" or', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8528080403030301, x1=0.7580941054901964, bottom=0.8629091009090908)),
#  Line(text='"Merrill") makes available certain investment products sponsored, managed, distributed or provided by', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8649292524242423, x1=0.8005649060784314, bottom=0.8750303130303029)),
#  Line(text='companies that are affiliates of Bank of America Corporation ("BofA Corp."). MLPF&S is a registered', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8770504645454544, x1=0.7914276054901964, bottom=0.8871515251515151)),
#  Line(text='broker-dealer, Member SIPC and a wholly owned subsidiary of BofA Corp. Banking products are', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.8891716766666666, x1=0.761871902156863, bottom=0.8992727372727273)),
#  Line(text='provided by Bank of America, N.A., and affiliated banks, Members FDIC and wholly owned subsidiaries', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.9012928887878787, x1=0.7977544345098038, bottom=0.9113939493939394)),
#  Line(text='of BofA Corp.', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.9134141009090908, x1=0.3121703072549019, bottom=0.9235151615151513)),
#  Line(text='Investment products: Are Not FDIC Insured ! Are Not Bank Guaranteed ! May Lose Value', bounding_box=BoundingBox(x0=0.2376470588235294, top=0.9273534948484848, x1=0.7246168139215686, bottom=0.9374545554545454)),
#  Line(text='PULL: B CYCLE: 7 SPEC: 0 DELIVERY: P TYPE: IMAGE: I BC: CT Page 1 of 4', bounding_box=BoundingBox(x0=0.06176470588235294, top=0.9785618281818181, x1=0.9023859529411764, bottom=0.9905568281818181))]

# %%
system_prompt = """You are a helpful assistant that extracts information from a document."""

user_prompt = f"""Extract the ending balance from bank statement along with the page number and line number its mentioned in.
Document:
{llm_input}
"""

# %%
response = processor.extract(
    model="gpt-5-mini",
    reasoning={"effort": "low"},
    response_format=EndingBalance,
    system_prompt=system_prompt,
    user_prompt=user_prompt,
)

# %%
response.model_dump()
# Out:
# {'ending_balance': 111.61,
#  'page_number_citation': 0,
#  'line_number_citations': [18]}
