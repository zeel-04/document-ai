# %%
from pydantic import BaseModel, Field
from typing_extensions import TypedDict

# %%
class Citation(TypedDict):
    value: float
    page: int
    lines: list[int]
    bboxes: list[dict]

class EndingBalance(BaseModel):
    ending_balance: float = Field(description="The ending balance of the account")

# %%
EndingBalance.model_json_schema()
# Out:
# {'properties': {'ending_balance': {'additionalProperties': {'type': 'number'},
#    'description': 'The ending balance of the account',
#    'title': 'Ending Balance',
#    'type': 'object'}},
#  'required': ['ending_balance'],
#  'title': 'EndingBalance',
#  'type': 'object'}
